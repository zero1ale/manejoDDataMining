# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
ruta = 'full_history/'

# %%
lst_stock = os.listdir(ruta)

# %%
len(lst_stock)
# Out:
# 8189

# %%
# %%time
for i,st in enumerate(lst_stock):
    print (st)
    aux = pd.read_csv(os.path.join(ruta,st))
    aux['stock'] = st.replace('.csv','')
    if i == 0:
        df = aux.copy()
    else:
        df = pd.concat([df,aux],ignore_index=True)
# Out:
# IWC.csv
# ARYA.csv
# RTH.csv
# IYT.csv
# AOR.csv
# BIMI.csv
# MDRX.csv
# EFX.csv
# TSLF.csv
# GOLD.csv
# AUMN.csv
# SRT.csv
# OSLE.csv
# KT.csv
# ZVO.csv
# ICON.csv
# TYHT.csv
# ENJ.csv
# USEG.csv
# FLXS.csv
# HBI.csv
# PRTS.csv
# NDRAW.csv
# CFFAU.csv
# RCI.csv
# ATI.csv
# HIE.csv
# OXBRW.csv
# IONS.csv
# IOSP.csv
# GD.csv
# DWDP.csv
# LGIH.csv
# FLSW.csv
# MYOK.csv
# ENLV.csv
# EMSG.csv
# SLYV.csv
# ZLAB.csv
# BMO.csv
# ITA.csv
# LEE.csv
# MMIN.csv
# AVYA.csv
# ATRA.csv
# ICD.csv
# SCO.csv
# RELV.csv
# GROW.csv
# CYTX.csv
# ISCA.csv
# FFIV.csv
# GXC.csv
# SCIF.csv
# GVP.csv
# WIRE.csv
# Y.csv
# PTLC.csv
# AMTD.csv
# STRS.csv
# PNRL.csv
# NHS.csv
# CURO.csv
# MYOV.csv
# GASX.csv
# HX.csv
# HJPX.csv
# PRK.csv
# OTTW.csv
# CTEK.csv
# CMP.csv
# HNW.csv
# FOR.csv
# BGY.csv
# MOSC.csv
# APU.csv
# SXT.csv
# VRS.csv
# IPAC.csv
# MTC.csv
# PRSC.csv
# RNDM.csv
# AFI.csv
# CHMA.csv
# ASYS.csv
# FTVA.csv
# VTL.csv
# RUSHB.csv
# RCII.csv
# RNG.csv
# YRIV.csv
# AROC.csv
# HFXE.csv
# OMCL.csv
# ...
